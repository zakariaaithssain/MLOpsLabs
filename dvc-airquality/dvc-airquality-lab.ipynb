# %% [markdown]
# # DVC AIR QUALITY LAB (TP 2 MLOPS)

# %%
# checkpoint0 
! python --version 
! dvc --version
! git --version 
! python -c "import pandas, sklearn; print('dependencies are ok')"
# Out:
# Python 3.14.2
# 3.67.1
# git version 2.52.0
# dependencies are ok

# %%
! mkdir -p data/raw data/processed data/features models metrics src

# %%
# I init git in the parent dir for all Labs, so I won't init it again here, I use the --subdir flag to indicate this to DVC
! dvc --subdir init 
! git add . 
! git commit -m "chore: init project dvc air quality"
# Out:
# ERROR: failed to initiate DVC - /home/zeco/Desktop/TPs/mlops/dvc-airquality is not tracked by any supported SCM tool (e.g. Git). Use `--no-scm` if you don't want to use any SCM or `--subdir` if initializing inside a subdirectory of a parent SCM repository.
# [main (root-commit) 69508a0] chore: init project dvc air quality
#  2 files changed, 114 insertions(+)
#  create mode 100644 dvc-airquality/dvc-airquality-lab.ipynb
#  create mode 100644 dvc-airquality/src/download_data.py
