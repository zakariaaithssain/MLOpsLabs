# %% [markdown]
# # DVC AIR QUALITY LAB (TP 2 MLOPS)

# %%
# checkpoint0 
! python --version 
! dvc --version
! git --version 
! python -c "import pandas, sklearn; print('dependencies are ok')"
# Out:
# Python 3.14.2
# 3.67.1
# git version 2.52.0
# dependencies are ok

# %%
! mkdir -p data/raw data/processed data/features models metrics src

# %%
# I init git in the parent dir for all Labs, so I won't init it again here
! dvc init 
! git add . 
! git commit -m "chore: init project dvc air quality"
